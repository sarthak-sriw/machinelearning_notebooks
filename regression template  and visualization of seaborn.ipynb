# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

d1=pd.read_csv(r'C:\Users\LENOVO\Desktop\Machine Learning A-Z Template Folder\Part 2 - Regression\Section 6 - Polynomial Regression\Polynomial_Regression\Position_Salaries.csv')


#split into independent and dependent variable
x=d1.iloc[:, 1:2].values
#we will not be adding no column
y=d1.iloc[:,-1].values

'''
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test=sc_x.transform(x_test)
sc_y = StandardScaler()
y_train = sc_y.transform(y_train)
'''
'''
from  sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state =0)
'''


# fitting " REGRESSION MODEL" to datasheet


#predicting the neew result 
y_pred = regressor.predict()

#visualizing linear regression result
plt.scatter(x,y,color ='red')
plt.plot(x,reg.predict(x),color ='blue')
plt.title('truth or bluff')
plt.xlabel('position')
plt.ylabel('Salary')
plt.show()

#visualizing linear regression result (for higher resolution and smoother curve)
x_grid = np.arange(min(x),max(x),0.01)
x_grid = x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color ='red')
plt.plot(x_grid,regressor.predict(x_grid),color ='blue')
plt.title('truth or bluff')
plt.xlabel('position')
plt.ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09bdb3b23b44> in <module>()
#      30
#      31 #predicting the neew result
# ---> 32 y_pred = regressor.predict()
#      33
#      34 #visualizing linear regression result
#
# NameError: name 'regressor' is not defined

# %%
import numpy as sm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes =True)
# %matplotlib inline

# %%
d1 = pd.read_csv(r'F:\csvfile\iris.data',header=-1)

# %%
d1.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
d1 = pd.read_csv?

# %%
d1 = pd.read_csv

# %%
d1 = pd.read_csv

# %% [markdown]
# #iris dataset

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.groupby('species').count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
iris['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
sns.pairplot?

# %%
sns.pairplot(iris,size = 3,aspect=1)
plt.show()

# %%
iris.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000199870C7B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019987007128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000199828B56D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199876AE160>]],
#       dtype=object)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
sns.violinplot(x='species',y= 'sepal_length' ,data =iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width' ,data =iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length' ,data =iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width' ,data =iris)

# %%
plt.boxplot
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
sns.boxplot(x='species',y= 'sepal_length' ,data =iris)
plt.subplot(2,2,2)
sns.boxplot(x='species',y='sepal_width' ,data =iris)
plt.subplot(2,2,3)
sns.boxplot(x='species',y='petal_length' ,data =iris)
plt.subplot(2,2,4)
sns.boxplot(x='species',y='petal_width' ,data =iris)

# %%
 sns.
